# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %% [markdown]
# ### Importing House Prediction dataset

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ### Pulling integer datatype features

# %%
df_int = df.select_dtypes("int")
df_int.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  OpenPorchSF  \
# 0         706           0        150  ...           0           61
# 1         978           0        284  ...         298            0
# 2         486           0        434  ...           0           42
# 3         216           0        540  ...           0           35
# 4         655           0        490  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %% [markdown]
# ### Heatmap of correlated values (without scaling)

# %%
sns.heatmap(df_int.corr());

# %% [markdown]
# ### Correlation values (without scaling)

# %%
df_int.corr()
# Out:
#                      Id  MSSubClass   LotArea  OverallQual  OverallCond  \
# Id             1.000000    0.011156 -0.033226    -0.028365     0.012609
# MSSubClass     0.011156    1.000000 -0.139781     0.032628    -0.059316
# LotArea       -0.033226   -0.139781  1.000000     0.105806    -0.005636
# OverallQual   -0.028365    0.032628  0.105806     1.000000    -0.091932
# OverallCond    0.012609   -0.059316 -0.005636    -0.091932     1.000000
# YearBuilt     -0.012713    0.027850  0.014228     0.572323    -0.375983
# YearRemodAdd  -0.021998    0.040581  0.013788     0.550684     0.073741
# BsmtFinSF1    -0.005024   -0.069836  0.214103     0.239666    -0.046231
# BsmtFinSF2    -0.005968   -0.065649  0.111170    -0.059119     0.040229
# BsmtUnfSF     -0.007940   -0.140759 -0.002618     0.308159    -0.136841
# TotalBsmtSF   -0.015415   -0.238518  0.260833     0.537808    -0.171098
# 1stFlrSF       0.010496   -0.251758  0.299475     0.476224    -0.144203
# ...

# %% [markdown]
# ### Performing Normalization

# %%
df_int_scaled = preprocessing.StandardScaler().fit_transform(df_int)
df_int_scaled = pd.DataFrame(df_int_scaled, columns=df_int.columns)
df_int_scaled.head()
# Out:
#          Id  MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0 -1.730865    0.073375 -0.207142     0.651479    -0.517200   1.050994
# 1 -1.728492   -0.872563 -0.091886    -0.071836     2.179628   0.156734
# 2 -1.726120    0.073375  0.073480     0.651479    -0.517200   0.984752
# 3 -1.723747    0.309859 -0.096897     0.651479    -0.517200  -1.863632
# 4 -1.721374    0.073375  0.375148     1.374795    -0.517200   0.951632
#
#    YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  \
# 0      0.878668    0.575425   -0.288653  -0.944591  ...   -0.752176
# 1     -0.429577    1.171992   -0.288653  -0.641228  ...    1.626195
# 2      0.830215    0.092907   -0.288653  -0.301643  ...   -0.752176
# 3     -0.720298   -0.499274   -0.288653  -0.061670  ...   -0.752176
# 4      0.733308    0.463568   -0.288653  -0.174865  ...    0.780197
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea   MiscVal  \
# ...

# %% [markdown]
# ### Heatmap of correlated values (with scaling)

# %%
sns.heatmap(df_int_scaled.corr());

# %% [markdown]
# ### Correlation (with scaling)

# %%
df_int_scaled.corr()
# Out:
#                      Id  MSSubClass   LotArea  OverallQual  OverallCond  \
# Id             1.000000    0.011156 -0.033226    -0.028365     0.012609
# MSSubClass     0.011156    1.000000 -0.139781     0.032628    -0.059316
# LotArea       -0.033226   -0.139781  1.000000     0.105806    -0.005636
# OverallQual   -0.028365    0.032628  0.105806     1.000000    -0.091932
# OverallCond    0.012609   -0.059316 -0.005636    -0.091932     1.000000
# YearBuilt     -0.012713    0.027850  0.014228     0.572323    -0.375983
# YearRemodAdd  -0.021998    0.040581  0.013788     0.550684     0.073741
# BsmtFinSF1    -0.005024   -0.069836  0.214103     0.239666    -0.046231
# BsmtFinSF2    -0.005968   -0.065649  0.111170    -0.059119     0.040229
# BsmtUnfSF     -0.007940   -0.140759 -0.002618     0.308159    -0.136841
# TotalBsmtSF   -0.015415   -0.238518  0.260833     0.537808    -0.171098
# 1stFlrSF       0.010496   -0.251758  0.299475     0.476224    -0.144203
# ...

# %% [markdown]
# ### Analyzing difference between the two

# %%
(df_int.corr() - df_int_scaled.corr()).sum()
# Out:
# Id              -1.060241e-15
# MSSubClass      -5.997373e-15
# LotArea          9.013190e-15
# OverallQual      1.306594e-14
# OverallCond      1.879790e-14
# YearBuilt       -1.132341e-14
# YearRemodAdd    -1.022359e-14
# BsmtFinSF1       3.154681e-14
# BsmtFinSF2       1.141838e-14
# BsmtUnfSF       -2.255834e-14
# TotalBsmtSF      1.140299e-14
# 1stFlrSF         8.687495e-15
# 2ndFlrSF        -5.111883e-14
# LowQualFinSF    -6.860831e-16
# GrLivArea       -2.600611e-14
# BsmtFullBath     4.489325e-14
# BsmtHalfBath    -6.175832e-15
# FullBath        -4.357669e-14
# HalfBath        -2.293738e-15
# BedroomAbvGr    -1.278665e-14
# KitchenAbvGr    -3.238295e-15
# TotRmsAbvGrd    -3.928021e-14
# Fireplaces      -9.542497e-15
# GarageCars       1.449882e-14
# GarageArea      -1.264266e-14
# WoodDeckSF       1.789064e-14
# OpenPorchSF     -1.084896e-14
# EnclosedPorch   -1.428068e-14
# 3SsnPorch       -9.332135e-16
# ScreenPorch      7.126895e-15
# PoolArea        -9.714451e-16
# ...

# %% [markdown]
# as you can see the difference comes in scale of e^-15 (approx zero)
